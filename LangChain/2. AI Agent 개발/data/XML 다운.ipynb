# %%
import law_XML_download as download

# %%
law_info = download.search_law("소득세법")
law_info
# Out:
#   🔍 검색 중: 소득세법
# [LawInfo(name='소득세법', mst='276127', ef_date='20260102', law_type='법률', pub_date='20251001', pub_no='21065')]

# %%
download.download_law_xml(law_info= law_info[0], output_path="./law_xml/소득세법.xml")
# Out:
#   ⬇️  다운로드: 소득세법 (MST=276127, 시행일=20260102)
#   ✅ 저장 완료: ./law_xml/소득세법.xml (1208.3 KB)
# True

# %%
# 시행령/시행규칙까지 한번에
download.download("소득세법", include_sub=True)

# # 여러 법령 한꺼번에
# for name in ["법인세법", "부가가치세법", "종합부동산세법"]:
#     download(name, include_sub=True)
# Out:
#   🔍 검색 중: 소득세법
#   ⬇️  다운로드: 소득세법 (MST=276127, 시행일=20260102)
#   ✅ 저장 완료: ./law_xml\소득세법.xml (1208.3 KB)
#   🔍 검색 중: 소득세법 시행령
#   ⬇️  다운로드: 소득세법 시행령 (MST=282973, 시행일=20260201)
#   ✅ 저장 완료: ./law_xml\소득세법_시행령.xml (2938.3 KB)
#   🔍 검색 중: 소득세법 시행규칙
#   ⬇️  다운로드: 소득세법 시행규칙 (MST=282651, 시행일=20260102)
#   ✅ 저장 완료: ./law_xml\소득세법_시행규칙.xml (6472.7 KB)
