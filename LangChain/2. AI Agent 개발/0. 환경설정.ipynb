# %%
# powershell -ExecutionPolicy ByPass -c "irm https://astral.sh/uv/install.ps1 | iex"

# uv sync

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# uv로 미리 담지 못한 패키지들은 uv add ~~~로 추가해주면
# 설치 및 toml, lock 파일 업데이트까지 됨
from langchain_anthropic import ChatAnthropic

llm = ChatAnthropic(model= 'claude-sonnet-4-20250514')

query = '복구충당부채에 대해서 설명해줘'

answer = llm.invoke(query)

print(answer)
# Out:
# AIMessage(content='복구충당부채(Asset Retirement Obligation, ARO)는 기업이 운영하는 자산을 미래에 철거하거나 복구해야 할 법적·계약적 의무와 관련하여 인식하는 부채입니다.\n\n## 주요 특징\n\n### 1. 발생 요건\n- **법적 의무**: 법령, 규정에 의한 복구 의무\n- **의제적 의무**: 계약상 또는 기업의 공표된 정책으로 인한 의무\n- **과거 사건**: 자산의 취득, 건설, 개발 또는 정상적인 운영\n\n### 2. 회계처리\n```\n차) 유형자산 (복구원가)     xxx\n  대) 복구충당부채           xxx\n```\n\n- 복구비용을 관련 자산의 취득원가에 포함\n- 복구충당부채는 현재가치로 평가\n- 시간경과에 따른 할인액 상각은 이자비용으로 처리\n\n### 3. 측정 방법\n- **최초 측정**: 복구비용의 현재가치\n- **후속 측정**: 할인율 변동, 복구시점 변경, 복구비용 추정치 변동 반영\n\n## 적용 사례\n\n### 대표적인 업종\n- **석유·가스**: 해상 시추시설, 송유관 철거\n- **광업**: 광산 복구, 환경 정화\n- **원자력**: 원전 해체, 폐기물 처리\n- **화학**: 오염 부지 정화\n\n### 실무 예시\n```\n예) 해상 시추시설 설치\n- 시설 취득원가: 1,000억원\n- 20년 후 철거비용 추정: 100억원\n- 할인율: 5%\n\n복구비용 현재가치 = 100억원 ÷ (1.05)^20 = 약 38억원\n\n차) 시추시설 1,038억원\n  대) 현금 1,000억원\n  대) 복구충당부채 38억원\n```\n\n## 회계기준상 주요 고려사항\n\n### K-IFRS 1037호 (충당부채)\n- 복구의무가 현재의무인지 판단\n- 신뢰성 있는 추정 가능성\n- 할인율의 적정성\n\n### 공시 요구사항\n- 복구충당부채의 성격과 예상 지급시기\n- 금액 추정의 불확실성\n- 기간 중 증감 내역\n\n복구충당부채는 환경 규제가 강화되면서 점점 중요해지고 있는 회계 항목입니다.', additional_kwargs={}, response_metadata={'id': 'msg_01RGuqBwUkhvpgC1GUXU9mXt', 'model': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 25, 'output_tokens': 816, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-20250514'}, id='run--5518aec9-d23b-46dc-b9c7-1fd2e976d5a2-0', usage_metadata={'input_tokens': 25, 'output_tokens': 816, 'total_tokens': 841, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})
