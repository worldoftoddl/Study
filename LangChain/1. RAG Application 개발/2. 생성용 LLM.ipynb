# %%
# %pip install -q python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# #### 1. OpenAI 생성

# %%
# %pip install langchain-openai
# Out:
# Requirement already satisfied: langchain-openai in c:\users\won_9\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-openai) (1.2.6)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-openai) (2.8.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.4.48)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (2.10.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (4.12.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\won_9\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain-openai) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\won_9\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\won_9\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\won_9\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\won_9\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (2.32.3)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\won_9\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.23.0)
# Requirement already satisfied: anyio in c:\users\won_9\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (4.12.0)
# Requirement already satisfied: certifi in c:\users\won_9\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\won_9\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in c:\users\won_9\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\won_9\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\won_9\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\won_9\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\won_9\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\won_9\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\won_9\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\won_9\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain-openai) (2.27.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\won_9\anaconda3\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2024.11.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\won_9\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\won_9\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (2.3.0)
# Requirement already satisfied: colorama in c:\users\won_9\anaconda3\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import ChatOpenAI

open_llm = ChatOpenAI()

# %%
open_ai_message = open_llm.invoke('내일 서울 날씨는 어때?')

# %%
open_ai_message.content
# Out:
# '내일 서울은 오전에 맑은 날씨가 예상되지만, 오후부터 흐려지며 가끔 비가 오는 확률이 있습니다. 최저기온은 10도, 최고기온은 18도로 어제보다 조금 더 높은 기온이 예상됩니다. 필요에 따라서 우산을 챙기시는 것이 좋을 것 같아요.'

# %% [markdown]
# #### 2. Upstage 생성

# %%
# %pip install langchain-upstage
# Out:
# Collecting langchain-upstage
#   Downloading langchain_upstage-0.7.5-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.3 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-upstage) (1.2.6)
# Requirement already satisfied: langchain-openai<2.0.0,>=1.0.2 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-upstage) (1.1.0)
# Collecting pypdf<5.0.0,>=4.2.0 (from langchain-upstage)
#   Downloading pypdf-4.3.1-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-upstage) (2.32.3)
# Collecting tokenizers<0.21.0,>=0.20.0 (from langchain-upstage)
#   Downloading tokenizers-0.20.3-cp313-none-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain-upstage) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain-upstage) (0.4.48)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain-upstage) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain-upstage) (2.10.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain-upstage) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain-upstage) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain-upstage) (4.12.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain-upstage) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\won_9\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.3->langchain-upstage) (2.1)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-openai<2.0.0,>=1.0.2->langchain-upstage) (2.8.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-openai<2.0.0,>=1.0.2->langchain-upstage) (0.12.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\won_9\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-upstage) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\won_9\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-upstage) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\won_9\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-upstage) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\won_9\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-upstage) (0.23.0)
# Requirement already satisfied: anyio in c:\users\won_9\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-upstage) (4.12.0)
# Requirement already satisfied: certifi in c:\users\won_9\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-upstage) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\won_9\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-upstage) (1.0.9)
# Requirement already satisfied: idna in c:\users\won_9\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-upstage) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\won_9\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-upstage) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\won_9\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai<2.0.0,>=1.0.2->langchain-upstage) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\won_9\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai<2.0.0,>=1.0.2->langchain-upstage) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\won_9\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai<2.0.0,>=1.0.2->langchain-upstage) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\won_9\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai<2.0.0,>=1.0.2->langchain-upstage) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\won_9\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.3->langchain-upstage) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\won_9\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.3->langchain-upstage) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\won_9\anaconda3\lib\site-packages (from requests<3.0.0,>=2.31.0->langchain-upstage) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\won_9\anaconda3\lib\site-packages (from requests<3.0.0,>=2.31.0->langchain-upstage) (2.3.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\won_9\anaconda3\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai<2.0.0,>=1.0.2->langchain-upstage) (2024.11.6)
# Collecting huggingface-hub<1.0,>=0.16.4 (from tokenizers<0.21.0,>=0.20.0->langchain-upstage)
#   Downloading huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: filelock in c:\users\won_9\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<0.21.0,>=0.20.0->langchain-upstage) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\won_9\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<0.21.0,>=0.20.0->langchain-upstage) (2025.3.2)
# Requirement already satisfied: colorama in c:\users\won_9\anaconda3\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai<2.0.0,>=1.0.2->langchain-upstage) (0.4.6)
# Downloading langchain_upstage-0.7.5-py3-none-any.whl (20 kB)
# Downloading pypdf-4.3.1-py3-none-any.whl (295 kB)
# Downloading tokenizers-0.20.3-cp313-none-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 32.4 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    --------------------------------------- 566.1/566.1 kB 19.3 MB/s eta 0:00:00
# Installing collected packages: pypdf, huggingface-hub, tokenizers, langchain-upstage
#
#    ---------------------------------------- 0/4 [pypdf]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ------------------------------ --------- 3/4 [langchain-upstage]
#    ---------------------------------------- 4/4 [langchain-upstage]
#
# Successfully installed huggingface-hub-0.36.0 langchain-upstage-0.7.5 pypdf-4.3.1 tokenizers-0.20.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_upstage import ChatUpstage

upstage_llm = ChatUpstage()

# %%
upstage_ai_message = upstage_llm.invoke('내일 서울 날씨는 어때?')
upstage_ai_message.content
# Out:
# '내일 서울의 날씨는 구름이 조금 끼고, 아침 최저기온은 10도, 낮 최고기온은 18도로 예상됩니다. 전반적으로 따뜻한 봄날씨가 예상되며, 야외활동하기에 적합한 날씨일 것입니다. 하지만, 항상 최신의 날씨 예보를 확인하시는 것이 좋습니다.'

# %% [markdown]
# #### 3. Anthropic 생성

# %%
# %pip install langchain-anthropic
# Out:
# Collecting langchain-anthropic
#   Downloading langchain_anthropic-1.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting anthropic<1.0.0,>=0.75.0 (from langchain-anthropic)
#   Downloading anthropic-0.75.0-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-anthropic) (1.2.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-anthropic) (2.10.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\won_9\anaconda3\lib\site-packages (from anthropic<1.0.0,>=0.75.0->langchain-anthropic) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\won_9\anaconda3\lib\site-packages (from anthropic<1.0.0,>=0.75.0->langchain-anthropic) (1.9.0)
# Collecting docstring-parser<1,>=0.15 (from anthropic<1.0.0,>=0.75.0->langchain-anthropic)
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\won_9\anaconda3\lib\site-packages (from anthropic<1.0.0,>=0.75.0->langchain-anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\won_9\anaconda3\lib\site-packages (from anthropic<1.0.0,>=0.75.0->langchain-anthropic) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\won_9\anaconda3\lib\site-packages (from anthropic<1.0.0,>=0.75.0->langchain-anthropic) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\won_9\anaconda3\lib\site-packages (from anthropic<1.0.0,>=0.75.0->langchain-anthropic) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\won_9\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->anthropic<1.0.0,>=0.75.0->langchain-anthropic) (3.7)
# Requirement already satisfied: certifi in c:\users\won_9\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.75.0->langchain-anthropic) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\won_9\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.75.0->langchain-anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\won_9\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic<1.0.0,>=0.75.0->langchain-anthropic) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-anthropic) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-anthropic) (0.4.48)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-anthropic) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-anthropic) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-anthropic) (9.0.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\won_9\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-anthropic) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\won_9\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.0->langchain-anthropic) (2.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\won_9\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-anthropic) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\won_9\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-anthropic) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\won_9\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-anthropic) (2.32.3)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\won_9\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-anthropic) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\won_9\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\won_9\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\won_9\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-anthropic) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\won_9\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-anthropic) (2.3.0)
# Downloading langchain_anthropic-1.3.0-py3-none-any.whl (45 kB)
# Downloading anthropic-0.75.0-py3-none-any.whl (388 kB)
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Installing collected packages: docstring-parser, anthropic, langchain-anthropic
#
#    ------------- -------------------------- 1/3 [anthropic]
#    ------------- -------------------------- 1/3 [anthropic]
#    ------------- -------------------------- 1/3 [anthropic]
#    ------------- -------------------------- 1/3 [anthropic]
#    ------------- -------------------------- 1/3 [anthropic]
#    ------------- -------------------------- 1/3 [anthropic]
#    ------------- -------------------------- 1/3 [anthropic]
#    ------------- -------------------------- 1/3 [anthropic]
#    ------------- -------------------------- 1/3 [anthropic]
#    ---------------------------------------- 3/3 [langchain-anthropic]
#
# Successfully installed anthropic-0.75.0 docstring-parser-0.17.0 langchain-anthropic-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_anthropic import ChatAnthropic

# Anthropic은 모델명 지정 必
claude_llm = ChatAnthropic(model = 'claude-3-haiku-20240307')

# %%
claude_ai_message = claude_llm.invoke('내일 서울 날씨는 어때?')

claude_ai_message.content
# Out:
# '네, 내일 서울의 날씨 예보를 살펴보겠습니다.\n\n내일 서울은 대체로 맑은 날씨가 예상됩니다. 아침 최저기온은 약 5도, 낮 최고기온은 약 15도 정도가 될 것으로 보입니다. 낮 동안 화창한 날씨가 지속될 것 같습니다. \n\n다만 늦은 오후부터 구름이 조금씩 많아져 차차 흐려질 것으로 전망됩니다. 그러나 비는 오지 않고 건조한 날씨가 유지될 것 같습니다.\n\n전반적으로 내일 서울은 쾌적한 날씨가 예상되니 외출하시기에 좋을 것 같습니다. 다만 일교차가 큰 편이므로 옷 입는 것에 유의하시는 것이 좋겠습니다.'

# %% [markdown]
# #### 4. Ollama 로컬 모델을 통한 생성

# %%
from langchain_ollama import ChatOllama

ollama_llm = ChatOllama(model = 'deepseek-r1:1.5b')

# %%
ollama_ai_message = ollama_llm.invoke('내일 서울 날씨는 어때?')

ollama_ai_message.content
# Out:
# '내일 Seoul lendary의昼夜 pattern을看一下み mind으로here에 나아보세요. 이는 24h内的 weather pattern을 보여주며, 내일 Seoul lendary에서 appropriate temperature and time settings를 사용할 수 있을 것입니다.'
