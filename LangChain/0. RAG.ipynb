# %% [markdown]
# ### RAG 개요

# %%
'''
RAG란 무엇인가?

Retrieval(검색)
    모델이 학습하지 않은 데이터를 검색하여
    
Augmented(증강)
    모델이 해당 정보를 아는 것 처럼
    
Generation(생성)
    답변을 생성하는 과정이다!!
'''

# %% [markdown]
# #### 개발자의 역할

# %%
'''
R A G 가운데 Generation은 LLM의 역할이다.

그러면 그 이전의 R과 A가 개발자의 역할이라고 볼 수 있겠다.
  즉, 모델이 참고할 데이터를 마련해서 전처리(!) 한 뒤, 잘 저장(!!)하여
  파이프라인과 프롬프트들(!!!)로 LLM에게 생성을 명령하는 것이 개발자의 역량이라고 할 수 있다.
'''
